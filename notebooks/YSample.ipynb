# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

# get stock info
msft.info

# get historical market data
hist = msft.history(period="max")

hist
# Out:
#               Open    High     Low   Close      Volume  Dividends  \
# Date
# 1986-03-13    0.06    0.06    0.06    0.06  1031788800       0.00
# 1986-03-14    0.06    0.07    0.06    0.06   308160000       0.00
# 1986-03-17    0.06    0.07    0.06    0.07   133171200       0.00
# 1986-03-18    0.07    0.07    0.06    0.06    67766400       0.00
# 1986-03-19    0.06    0.06    0.06    0.06    47894400       0.00
# ...            ...     ...     ...     ...         ...        ...
# 2020-05-18  185.23  185.68  183.45  184.40    35306600       0.00
# 2020-05-19  184.52  186.08  182.98  183.12    26799100       0.00
# 2020-05-20  184.81  185.85  183.94  185.66    31261300       0.51
# 2020-05-21  185.40  186.67  183.29  183.43    29090200       0.00
# 2020-05-22  183.19  184.46  182.75  183.76     4961277       0.00
#
#             Stock Splits
# Date
# 1986-03-13           0.0
# 1986-03-14           0.0
# 1986-03-17           0.0
# 1986-03-18           0.0
# 1986-03-19           0.0
# ...

# %%
# minimum processing to be compatible with OHLCFigure
# hist['datetime'] = pandas.to_datetime(dataframe.timestamp, unit="s")

from bokeh.models import ColumnDataSource
from bokeh.io import show
from bokeh.plotting import output_notebook

output_notebook()

hist.columns = [c.lower() for c in hist.columns]
hist['datetime'] = hist.index

cds = ColumnDataSource(hist, name="OHLC")

from bokeh_ta.ohlc import ohlc
plot = ohlc(source=cds)


show(plot(plot_height=320, tools='pan, wheel_zoom', toolbar_location="left",
               x_axis_type="datetime", y_axis_location="right",
               sizing_mode="scale_width"))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="2b583774-2b3a-4e2a-8bf2-cba7bf043030" data-root-id="1003"></div>

# %%
from pandas_ta import macd

macd_df = hist.ta.macd(fast=3, slow=6, signal=9)
macd_df['datetime'] = macd_df.index

cds = ColumnDataSource(macd_df, name="OHLC")

from bokeh_ta.macd import macd as macdplot
plot = macdplot(source=cds, fast=3, slow=6, signal=9)


show(plot(plot_height=320, tools='pan, wheel_zoom', toolbar_location="left",
               x_axis_type="datetime", y_axis_location="right",
               sizing_mode="scale_width"))
# Out:
#   <div class="bk-root" id="494f2d6c-d853-48de-a10f-f0e0e51a2034" data-root-id="1245"></div>
